# %% [markdown]
# ### String Matching Practice
#
# **(April 11, 2024)**

# %%
from tqdm.notebook import tqdm

# %% [markdown]
# #### Custom String Matching Score Functions

# %%
import string
import numpy as np

# %% [markdown]
# ### Loading in Data

# %%
import pandas as pd

# %%
# reading in election data; File is not stored locally in this repository
election_data = pd.read_csv('raw_feb_23_city_wide.csv', dtype=str)

# %%
election_data
# Out:
#          Last_Name First_Name Middle_Name Name_Style Street_Number  \
# 0       A Blessing    Rebecca         Ann        NaN          1722
# 1         A-Jaoudi     Edward         NaN        NaN          2503
# 2           Aaberg  Elizabeth    Margaret        NaN          3019
# 3             Aaby       Erik         NaN        NaN          1300
# 4             Aaby  Katherine       Diane        NaN          1854
# ...            ...        ...         ...        ...           ...
# 520556     Zytnick   Jonathon         NaN        NaN           425
# 520557     Zytnick       Kiva       Keane        NaN          1303
# 520558   Zywokarte    Michael      Donald        NaN          1265
# 520559   Zywokarte     Sandra       Leigh        NaN          1265
# 520560  Zyznieuski   Nicholas     Michael        NaN          2829
#
#           Street_Name Street_Type Street_Dir_Suffix Unit_Type  \
# 0                19th          ST                NW       APT
# 1       Ralph Ellison         Way                NE       NaN
# 2                15th          ST                NW       APT
# 3                 4th          St                SE       NaN
# 4                Park          Rd                NW       NaN
# ...               ...         ...               ...       ...
# 520556              L          ST                NW       NaN
# 520557         Newton          St                NE       NaN
# 520558            4th          St                SW       NaN
# 520559            4th          St                SW       NaN
# 520560    Connecticut         Ave                NW       NaN
#
#        Apartment_Number  ... SPECIAL ELECTION WARD 4 AND 8(Apr/28/2015)  \
# 0                   706  ...                                        NaN
# 1                   NaN  ...                                        NaN
# 2                     4  ...                                        NaN
# 3              UNIT 715  ...                                          N
# 4                   NaN  ...                                          N
# ...                 ...  ...                                        ...
# 520556              305  ...                                        NaN
# 520557              NaN  ...                                          N
# 520558              NaN  ...                                          N
# 520559              NaN  ...                                          N
# 520560              712  ...                                        NaN
#
#        DISTRICT OF COLUMBIA GENERAL ELECTI(Nov/04/2014)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 520556                                              NaN
# 520557                                                Y
# 520558                                                A
# 520559                                                A
# 520560                                              NaN
#
#        SPECIAL BD OF ED ELECTION WARD 8(Jul/15/2014)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                  N
# 4                                                  N
# ...                                              ...
# 520556                                           NaN
# 520557                                             N
# 520558                                             N
# 520559                                             N
# 520560                                           NaN
#
#        DC MAYORAL PRIMARY 2014(Apr/01/2014)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                         N
# ...                                     ...
# 520556                                  NaN
# 520557                                    Y
# 520558                                    A
# 520559                                    A
# 520560                                  NaN
#
#        DIST OF COLUMBIA AT-LARGE SPECIAL E(Apr/23/2013)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 520556                                              NaN
# 520557                                              NaN
# 520558                                                Y
# 520559                                                Y
# 520560                                              NaN
#
#        DISTRICT OF COLUMBIA GENERAL ELECTI(Nov/06/2012)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                     N
# 4                                                     A
# ...                                                 ...
# 520556                                              NaN
# 520557                                                P
# 520558                                                A
# 520559                                                A
# 520560                                              NaN
#
#        SPECIAL ELECTION WARD 5 COUNCIL(May/15/2012)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                                 N
# ...                                             ...
# 520556                                          NaN
# 520557                                            N
# 520558                                            N
# 520559                                            N
# 520560                                          NaN
#
#        DC PRESIDENTIAL PREF/COUNCIL PRIMAR(Apr/03/2012)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                     N
# ...                                                 ...
# 520556                                              NaN
# 520557                                              NaN
# 520558                                              NaN
# 520559                                              NaN
# 520560                                              NaN
#
#        RECALL SPECIAL ELECTION 4B04(Feb/28/2012)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                              N
# ...                                          ...
# 520556                                       NaN
# 520557                                         N
# 520558                                         N
# 520559                                         N
# 520560                                       NaN
#
#        2011 DISTRICT OF COLUMBIA SPECIAL E(Apr/26/2011)
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 520556                                              NaN
# 520557                                                A
# 520558                                                A
# 520559                                                A
# 520560                                              NaN
#
# [520561 rows x 39 columns]

# %%
# generating list of names
first_name_list = list(election_data['First_Name'])
last_name_list = list(election_data['Last_Name'])
full_name_list = [str(char1) + ' ' + str(char2) for char1, char2 in zip(first_name_list, last_name_list)]

# %% [markdown]
# #### Rapid Fuzzy Match
#
# https://rapidfuzz.github.io/RapidFuzz/Usage/fuzz.html#rapidfuzz.fuzz.partial_ratio

# %%
from rapidfuzz import fuzz

# %%
# https://rapidfuzz.github.io/RapidFuzz/Usage/fuzz.html#rapidfuzz.fuzz.partial_ratio

# %%
def score_function_fuzz(guess_full_name, full_name_list):

    full_name_score_dict = dict()
    for idx in tqdm(range(len(full_name_list))):

        # getting full name for row
        name_row = str(full_name_list[idx])

        # lowering strings    
        name_row = name_row.lower()
        guess_full_name = guess_full_name.lower()
    
        # compiling scores
        final_score = fuzz.ratio(guess_full_name, name_row)/100
        full_name_score_dict[idx] = final_score

    # sorting dictionary
    sorted_dictionary = dict(sorted(full_name_score_dict.items(), reverse=True, key=lambda item: item[1]))

    # top five key value pairs (indices and scores)
    indices_scores_list = list(sorted_dictionary.items())[:5]

    return indices_scores_list

# %% [markdown]
# #### Finding Similar Data Base Entries

# %%
# displaying last and first name only
election_data[['Last_Name', 'First_Name']]
# Out:
#          Last_Name First_Name
# 0       A Blessing    Rebecca
# 1         A-Jaoudi     Edward
# 2           Aaberg  Elizabeth
# 3             Aaby       Erik
# 4             Aaby  Katherine
# ...            ...        ...
# 520556     Zytnick   Jonathon
# 520557     Zytnick       Kiva
# 520558   Zywokarte    Michael
# 520559   Zywokarte     Sandra
# 520560  Zyznieuski   Nicholas
#
# [520561 rows x 2 columns]

# %%
# finding elmements in election database that are similar to a given string
score_function_fuzz('Alexandra Karabatos', full_name_list)
# Out:
#   0%|          | 0/520561 [00:00<?, ?it/s]
# [(247654, 0.9743589743589743),
#  (247699, 0.85),
#  (407872, 0.8333333333333335),
#  (261560, 0.8235294117647058),
#  (261711, 0.8235294117647058)]

# %%
# Testing the element
election_data.iloc[247654]
# Out:
# Last_Name                                           Karabatsos
# First_Name                                           Alexandra
# Middle_Name                                              Maria
# Name_Style                                                 NaN
# Street_Number                                             1300
# Street_Name                                                  K
# Street_Type                                                 ST
# Street_Dir_Suffix                                           SE
# Unit_Type                                                  APT
# Apartment_Number                                           302
# City_Name                                           Washington
# Zip_Code                                                 20003
# Registration_Date                                   2021-10-16
# Party                                                      DEM
# Precinct                                                 91.04
# SMD                                                       6B09
# ANC                                                         6B
# WARD                                                       6.0
# Voter Status                                               ACT
# 2022 GENERAL ELECTION(Nov/08/2022)                           A
# 2022 PRIMARY ELECTION(Jun/21/2022)                           A
# 2020 DC PRESIDENTIAL GENERAL ELECTI(Nov/03/2020)           NaN
# 2020 SPECIAL ELECTION WARD 2(Jun/16/2020)                  NaN
# 2020 DC PRESIDENTIAL PRIMARY ELECTI(Jun/02/2020)           NaN
# 2018 SPECIAL WARD 4 BOARD OF ED ELE(Dec/04/2018)           NaN
# 2018 DC GENERAL ELECTION(Nov/06/2018)                      NaN
# 2018 DC MAYORAL PRIMARY(Jun/19/2018)                       NaN
# 2016  DC PRESIDENTIALGENERAL ELECTI(Nov/08/2016)           NaN
# 2016 PRESIDENTIAL PRIMARY ELECTION(Jun/14/2016)            NaN
# SPECIAL ELECTION WARD 4 AND 8(Apr/28/2015)                 NaN
# DISTRICT OF COLUMBIA GENERAL ELECTI(Nov/04/2014)           NaN
# SPECIAL BD OF ED ELECTION WARD 8(Jul/15/2014)              NaN
# DC MAYORAL PRIMARY 2014(Apr/01/2014)                       NaN
# DIST OF COLUMBIA AT-LARGE SPECIAL E(Apr/23/2013)           NaN
# DISTRICT OF COLUMBIA GENERAL ELECTI(Nov/06/2012)           NaN
# SPECIAL ELECTION WARD 5 COUNCIL(May/15/2012)               NaN
# DC PRESIDENTIAL PREF/COUNCIL PRIMAR(Apr/03/2012)           NaN
# RECALL SPECIAL ELECTION 4B04(Feb/28/2012)                  NaN
# 2011 DISTRICT OF COLUMBIA SPECIAL E(Apr/26/2011)           NaN
# Name: 247654, dtype: object
